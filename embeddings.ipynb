# %% [markdown]
# # ПРЕДСКАЗАНИЕ РЕЗУЛЬТАТОВ ТУРНИРНЫХ ИГР ПО CS:GO

# %%
import os, tqdm, json, pickle, gc, zipfile, itertools, time
import pandas as pd
import numpy as np
from dateutil import parser
import warnings
warnings.filterwarnings('ignore')
from collections import defaultdict
from multiprocessing import Pool
import catboost as cb
from sklearn.model_selection import train_test_split, TimeSeriesSplit, cross_val_score, ParameterGrid, StratifiedKFold, cross_val_predict
from sklearn.metrics import roc_auc_score
from sklearn.inspection import permutation_importance
import optuna
from optuna.samplers import TPESampler
from tqdm.contrib.concurrent import process_map  
import seaborn as sns
import matplotlib.pyplot as plt
import shap 
from sklearn.model_selection import KFold
from nancorrmp.nancorrmp import NaNCorrMp
# from pathos.multiprocessing import ProcessingPool as Pool
import multiprocessing as mp
from datetime import datetime
from optuna.samplers import TPESampler

from keras.models import Model, Sequential
from keras.layers import Input, Dense, Dropout, Activation
from keras.layers import Concatenate, Reshape, SpatialDropout1D
from keras.layers.embeddings import Embedding
from keras import regularizers

# %%
def add_profile(d_game):

    def add_global_info(d_game):

        d = {}

        d['id'] = d_game['id'] 
        d['date'] = parser.parse(d_game['begin_at'])        
        d['year'] = d['date'].year
        d['month'] = d['date'].month
        d['day'] = d['date'].day
        d['weekday'] = d['date'].weekday()
        d['hour'] = d['date'].hour
        d['number_of_games'] = d_game['match']['number_of_games']
        d['map_id'] = d_game['map']['id']
        d['league_id'] = d_game['match']['league']['id']
        d['serie_id'] = d_game['match']['serie']['id']
        d['tournament_id'] = d_game['match']['tournament']['id']
        d['serie_tier'] = d_game['match']['serie']['tier']

        return d
        
    # идентификаторы актуальных карт
    l_map2use = [1, 2, 6, 7, 8, 20, 31]
    # ключи со статистикой игрока
    l_stat_keys = ['adr', 'assists', 'deaths', 'first_kills_diff', 'flash_assists', 
                   'headshots', 'k_d_diff', 'kast', 'kills', 'rating']
    l_stat_keys_v2 = ['assists', 'deaths', 'flash_assists', 'headshots', 'kills']


    # информация об игре
    d_info = add_global_info(d_game)
    
    if d_info['map_id'] in l_map2use:  

        d_r1 = d_game['rounds'][0]
        if d_r1['round']==1:
            
            # информация о раундах
            df_rounds = pd.DataFrame.from_records(d_game['rounds'])
            start_ct_id =d_r1['ct']   
            winner_id = df_rounds['winner_team'].value_counts().idxmax()
            maxround = df_rounds['round'].max()
            d_h1_win_count = df_rounds.query('round<=15')['winner_team'].value_counts().to_dict()
            d_h2_win_count = df_rounds.query('round>15')['winner_team'].value_counts().to_dict()
            d_h1_outcome_count = df_rounds.query('round<=15')['outcome'].value_counts().to_dict()
            d_h2_outcome_count = df_rounds.query('round>15')['outcome'].value_counts().to_dict()        

            L = []
            counter = 0
            # информация об игроках
            for p in d_game['players']:
                counter+=1

                d = {}
                d.update(d_info)

                # идентификатор игрока
                d['player_id'] = p['player']['id']
                # идентификатор команды
                d['team_id'] = p['team']['id']
                # идентификатор оппонента
                d['opponent_id'] = p['opponent']['id']

                # национальность игрока
                d['player_nationality']  = p['player']['nationality']
                d['player_hometown']  = p['player']['hometown']
                # дата рождения игрока
                d['player_birthday'] = p['player']['birthday']
                # страна команды
                d['team_location']  = p['team']['location']

                # сторона начала
                d['start_ct']= 1 if start_ct_id==d['team_id'] else 0
                # победа
                d['win'] = 1 if winner_id==d['team_id'] else 0
                # все раундов в игре
                d['maxround'] = maxround

                # число выигранных раундов в 1-ой половине игры
                try:
                    d['h1_win_count'] = d_h1_win_count[d['team_id']]
                except:
                    d['h1_win_count'] = 0 
                # число выигранных раундов во 2-ой половине игры
                try:
                    d['h2_win_count'] = d_h2_win_count[d['team_id']]
                except:
                    d['h2_win_count'] = 0 
                # исходы раундов в 1-ой половине игры
                for k, v in d_h1_outcome_count.items():
                    d[f'h1_outcome_{k}_count'] = v
                # исходы раундов во 2-ой половине игры
                for k, v in d_h2_outcome_count.items():
                    d[f'h2_outcome_{k}_count'] = v            

                # статистика игрока
                d.update({k:p[k] if pd.notnull(p[k]) else 0.0 for k in l_stat_keys})
                d.update({f'{k}_per_round':p[k]/maxround if pd.notnull(p[k]) else 0.0 for k in l_stat_keys_v2})

                L.append(d)
            if counter==10:
                return L
            else:
                return None
        else:
            return None

# %%
PATH_TO_RESPONSES = 'L_games_collection'

# %%
L_FILENAMES = os.listdir(PATH_TO_RESPONSES)
L_RESPONSES = []
for fnm in tqdm.tqdm(L_FILENAMES):
    try:
        pth = os.path.join(PATH_TO_RESPONSES, fnm)
        with open(pth, 'r') as f:
            d_rsp = json.load(f)
        L_RESPONSES.append(d_rsp)
    except:
        pass
idx_ordered = np.argsort([d_game['id'] for d_game in L_RESPONSES])[::-1]
L_RESPONSES = np.array(L_RESPONSES)[idx_ordered].tolist()
# Out:
# 100%|██████████| 57985/57985 [00:20<00:00, 2875.50it/s]

# %%
L_GLOBAL_KEYS = [
                 
  'id',
  'date', 'timestamp',
  'year', 'month', 'day', 'weekday', 'hour',
  'number_of_games',
  'map_id',
  'league_id', 'serie_id', 'tournament_id',
  'serie_tier'  
               
]

L_PLAYER_KEYS = [
                 
  'id', 'nationality','hometown', 'age',

  'adr','assists', 'deaths', 'first_kills_diff', 'flash_assists', 'headshots',
  'k_d_diff', 'kast', 'kills', 'rating', 'assists_per_round',
  'deaths_per_round', 'flash_assists_per_round', 'headshots_per_round',
  'kills_per_round'

]

L_TEAM_KEYS = [
               
  'id', 'location',

  'start_ct',
  
  'win', 'maxround',
  
  'h1_win_count',
  'h2_win_count', 'h1_outcome_eliminated_count',
  'h1_outcome_exploded_count', 'h1_outcome_defused_count',
  'h2_outcome_eliminated_count', 'h2_outcome_exploded_count',
  'h2_outcome_defused_count', 'h1_outcome_timeout_count', 'h2_outcome_timeout_count'
]

L_profile = []
for d_rsp in tqdm.tqdm(L_RESPONSES):
    try:
        L_profile.extend(add_profile(d_rsp))
    except:
        pass
df_profile = pd.DataFrame.from_records(L_profile)
df_profile['timestamp'] = df_profile['date'].apply(lambda x: x.timestamp())
df_profile['player_birthday_year'] = df_profile['player_birthday'].astype('datetime64').dt.year
df_profile['player_age'] = df_profile['year'] - df_profile['player_birthday_year']
del L_profile
gc.collect()

df_profile = df_profile.rename(columns = dict(zip(
                                ['player_nationality','player_hometown', 'player_age', 'team_location'],
                                ['nationality','hometown', 'age', 'location'])
                                ))

ser_nunique_players4game = df_profile.groupby('id')['player_id'].nunique()
df_profile = df_profile[df_profile['id'].isin(ser_nunique_players4game[ser_nunique_players4game==10].index)]

assert (df_profile.groupby('id')['player_id'].nunique()==10).all()

L_rows = []
for game_id, subdf in tqdm.tqdm(df_profile.groupby('id')):
  d = subdf[L_GLOBAL_KEYS].iloc[0].to_dict()
  subdf =subdf.sort_values('team_id').drop('id', 1)  
  for i in range(len(subdf)):    
    d.update(subdf.iloc[[i]]\
                  .rename(columns = {'player_id':'id'})\
                  [L_PLAYER_KEYS].add_prefix(f'player{i+1}__')\
                  .iloc[0].to_dict()
              )
  for i, (team_id, subsubdf) in enumerate(subdf.groupby('team_id')):
    d.update(subsubdf\
              .rename(columns = {'team_id':'id'})\
              [L_TEAM_KEYS].add_prefix(f'team{i+1}__')\
              .iloc[0].to_dict()
              )
  L_rows.append(d)     
df_profile = pd.DataFrame.from_records(L_rows) 
del L_rows
gc.collect()

df_profile.to_pickle('df_profile.pickle')
# Out:
# 100%|██████████| 34975/34975 [08:55<00:00, 65.31it/s]

# %% [markdown]
# ### описание датасета
#
# |ключ|описание|
# |---|---|
# |id|идентификатор игры|
# |date|дата|
# |year|год|
# |month|месяц|
# |day|день|
# |weekday|день недели|
# |hour|час|
# |number_of_games|число игр в матче|
# |map_id|идентификатор карты|
# |league_id|идентификатор лиги|
# |serie_id|идентфикатор серии|
# |tournament_id|идентфикатор турнира|
# |serie_tier|ранг серии|
# |player_id|идентификатор игрока|
# |team_id|идентификатор команды игрока|
# |opponent_id|идентфикатор противоположной команды|
# |player_nationality|национальность игрока|
# |player_birthday|дата рождения игрока|
# |team_location|страна команды|
# |start_ct|старт игры за контр-террористов|
# |win|победа|
# |maxround|число раундов вигре|
# |h1_win_count|число выигранных раундов в 1-ой половине игры|
# |h2_win_count|число выигранных раундов во 2-ой половине игры|
# |h1_outcome_eliminated_count|число полных убийств команды соперника в 1-ой половине игры|
# |h1_outcome_exploded_count|число взорвавшихся бомб в 1-ой половине игры|
# |h1_outcome_defused_count|число обезвреженных бомб в 1-ой половине игры|
# |h2_outcome_eliminated_count|...|
# |h2_outcome_exploded_count|...|
# |h2_outcome_defused_count|...|
# |h1_outcome_timeout_count|число раундов с истекшим временем  в 1-ой половине игры|
# |h2_outcome_timeout_count|...|
# |adr|средний урон в раунде|
# |assists|число помощей в убийствах|
# |deaths|число смертей|
# |first_kills_diff|разница во времени между первыми убийствами команд|
# |flash_assists|число световых гранат, после которых были совершены убийства|
# |headshots|число убиййств в голову|
# |k_d_diff|отношение числа убийств к числу смертей?|
# |kast|% раундов, в которых игрок имел убийство, ассист, выжил или был разменен|
# |kills|число убийств|
# |rating|рейтинг|
# |assists_per_round|число ассистов в расчете на 1 раунд|
# |deaths_per_round|...|
# |flash_assists_per_round|...|
# |headshots_per_round|...|
# |kills_per_round|...|

# %%
df_profile = pd.read_pickle('df_profile.pickle')

# %%
df_profile.head()
# Out:
#    id                      date     timestamp  year  month  day  weekday  \
# 0   1 2017-10-29 13:55:00+00:00  1.509285e+09  2017     10   29        6
# 1   2 2017-10-29 14:47:00+00:00  1.509288e+09  2017     10   29        6
# 2   6 2017-10-29 09:30:00+00:00  1.509269e+09  2017     10   29        6
# 3   7 2017-10-29 10:30:00+00:00  1.509273e+09  2017     10   29        6
# 4   8 2017-10-29 11:30:00+00:00  1.509277e+09  2017     10   29        6
#
#    hour  number_of_games  map_id  ...  team2__h1_win_count  \
# 0    13                5       1  ...                   10
# 1    14                5       2  ...                    6
# 2     9                3       6  ...                    5
# 3    10                3       1  ...                   10
# 4    11                3       2  ...                    5
#
#    team2__h2_win_count  team2__h1_outcome_eliminated_count  \
# 0                    6                                  11
# 1                    0                                  10
# 2                    9                                  11
# 3                    6                                  13
# 4                   11                                  12
#
#   team2__h1_outcome_exploded_count  team2__h1_outcome_defused_count  \
# 0                              1.0                              1.0
# 1                              2.0                              2.0
# 2                              3.0                              1.0
# 3                              NaN                              1.0
# 4                              2.0                              1.0
#
#   team2__h2_outcome_eliminated_count team2__h2_outcome_exploded_count  \
# 0                                8.0                              2.0
# 1                                5.0                              2.0
# 2                               11.0                              2.0
# 3                               11.0                              2.0
# 4                                8.0                              4.0
#
#    team2__h2_outcome_defused_count  team2__h1_outcome_timeout_count  \
# 0                              1.0                              2.0
# 1                              NaN                              1.0
# 2                              1.0                              NaN
# 3                              2.0                              1.0
# 4                              NaN                              NaN
#
#    team2__h2_outcome_timeout_count
# 0                              NaN
# 1                              NaN
# 2                              1.0
# 3                              NaN
# 4                              NaN
#
# [5 rows x 234 columns]

# %%
L_p_id_keys = [
    'player1__id', 'player2__id', 'player3__id', 'player4__id',
    'player5__id', 'player6__id', 'player7__id', 'player8__id',
    'player9__id', 'player10__id'
]
L_t_id_keys = ['team1__id', 'team2__id']

cat_features = L_p_id_keys+L_t_id_keys

# %%
# del df_to_embed
# gc.collect()

# %%
df_to_embed = df_profile[cat_features].fillna('default').astype('str')

# длина комбинации
for n in tqdm.tqdm_notebook([2, 3]):
    # комбинации
    L_cmb = list(itertools.combinations(cat_features, n))
    for cmb in tqdm.tqdm_notebook(L_cmb, total = len(L_cmb)):
        cmb = list(cmb)
        new_key = '-'.join(cmb)
        df_to_embed[new_key] = df_to_embed[cmb].apply(lambda x: '-'.join(x), axis = 1)
cat_features = df_to_embed.columns
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/66 [00:00<?, ?it/s]
#   0%|          | 0/220 [00:00<?, ?it/s]

# %%
df_to_embed.head()
# Out:
#   player1__id player2__id player3__id player4__id player5__id player6__id  \
# 0       17497       17498       17499       17500       17501       17502
# 1       17497       17498       17499       17500       17501       17502
# 2       17507       17508       17509       17510       17511       17512
# 3       17507       17508       17509       17510       17511       17512
# 4       17507       17508       17509       17510       17511       17512
#
#   player7__id player8__id player9__id player10__id  ...  \
# 0       17503       17504       17505        17506  ...
# 1       17503       17504       17505        17506  ...
# 2       17513       17514       17515        17516  ...
# 3       17513       17514       17515        17516  ...
# 4       17513       17514       17515        17516  ...
#
#   player8__id-player9__id-player10__id player8__id-player9__id-team1__id  \
# 0                    17504-17505-17506                  17504-17505-3207
# 1                    17504-17505-17506                  17504-17505-3207
# 2                    17514-17515-17516                  17514-17515-3209
# 3                    17514-17515-17516                  17514-17515-3209
# 4                    17514-17515-17516                  17514-17515-3209
#
#   player8__id-player9__id-team2__id player8__id-player10__id-team1__id  \
# 0                  17504-17505-3288                   17504-17506-3207
# 1                  17504-17505-3288                   17504-17506-3207
# 2                  17514-17515-3210                   17514-17516-3209
# 3                  17514-17515-3210                   17514-17516-3209
# 4                  17514-17515-3210                   17514-17516-3209
#
#   player8__id-player10__id-team2__id player8__id-team1__id-team2__id  \
# 0                   17504-17506-3288                 17504-3207-3288
# 1                   17504-17506-3288                 17504-3207-3288
# 2                   17514-17516-3210                 17514-3209-3210
# 3                   17514-17516-3210                 17514-3209-3210
# 4                   17514-17516-3210                 17514-3209-3210
#
#   player9__id-player10__id-team1__id player9__id-player10__id-team2__id  \
# 0                   17505-17506-3207                   17505-17506-3288
# 1                   17505-17506-3207                   17505-17506-3288
# 2                   17515-17516-3209                   17515-17516-3210
# 3                   17515-17516-3209                   17515-17516-3210
# 4                   17515-17516-3209                   17515-17516-3210
#
#   player9__id-team1__id-team2__id player10__id-team1__id-team2__id
# 0                 17505-3207-3288                  17506-3207-3288
# 1                 17505-3207-3288                  17506-3207-3288
# 2                 17515-3209-3210                  17516-3209-3210
# 3                 17515-3209-3210                  17516-3209-3210
# 4                 17515-3209-3210                  17516-3209-3210
#
# [5 rows x 298 columns]

# %%
class KerasEmbeddingTransformer():

    def __init__(self, min_n_dim, max_n_dim):
        self.min_n_dim = min_n_dim
        self.max_n_dim = max_n_dim
    def fit(self, df_to_embed):
        cat_features = df_to_embed.columns
        # размерность входного слоя
        self.inputs = []
        # эмбеддинги
        self.embeddings = []

        # признаки, для которых строим  эмбеддинги
        for col in tqdm.tqdm_notebook(cat_features):
            # мощность признака
            cardinality = int(np.ceil(df_to_embed[col].nunique() + 2))
            # задаем размерность ембеддинга
            # от 2, до 50, или cardinality//2
            embedding_dim = max(min((cardinality)//2, self.max_n_dim),self.min_n_dim)
            print(f'{col}: cardinality : {cardinality} and embedding dim: {embedding_dim}')
            col_inputs = Input(shape=(1,))
            # определяем ембеддинг
            embedding = Embedding(cardinality, embedding_dim,
                                  input_length=1, name=col+"__embed")(col_inputs)
            # регуляризуем (выбрасываем 10%)
            embedding = SpatialDropout1D(0.1)(embedding)
            # делаем плоским
            embedding = Reshape(target_shape=(embedding_dim,))(embedding)
            # добавляем размерность для входного слоя
            self.inputs.append(col_inputs)
            # добавляем слой с эмбеддингом
            self.embeddings.append(embedding)

        return self

    def transform(self):
        
        return self.inputs, self.embeddings

embed_transformer = KerasEmbeddingTransformer(min_n_dim=2, max_n_dim=50)
embed_transformer.fit(df_to_embed)
emb_inputs, emb_layer = embed_transformer.transform()
# Out:
#   0%|          | 0/298 [00:00<?, ?it/s]
# player1__id: cardinality : 1029 and embedding dim: 50
# player2__id: cardinality : 1284 and embedding dim: 50
# player3__id: cardinality : 1412 and embedding dim: 50
# player4__id: cardinality : 1453 and embedding dim: 50
# player5__id: cardinality : 1490 and embedding dim: 50
# player6__id: cardinality : 1276 and embedding dim: 50
# player7__id: cardinality : 1603 and embedding dim: 50
# player8__id: cardinality : 1755 and embedding dim: 50
# player9__id: cardinality : 1859 and embedding dim: 50
# player10__id: cardinality : 1890 and embedding dim: 50
# team1__id: cardinality : 796 and embedding dim: 50
# team2__id: cardinality : 1259 and embedding dim: 50
# player1__id-player2__id: cardinality : 1846 and embedding dim: 50
# player1__id-player3__id: cardinality : 2106 and embedding dim: 50
# player1__id-player4__id: cardinality : 2232 and embedding dim: 50
# player1__id-player5__id: cardinality : 2264 and embedding dim: 50
# player1__id-player6__id: cardinality : 11664 and embedding dim: 50
# player1__id-player7__id: cardinality : 12219 and embedding dim: 50
# player1__id-player8__id: cardinality : 12434 and embedding dim: 50
# player1__id-player9__id: cardinality : 12571 and embedding dim: 50
# player1__id-player10__id: cardinality : 12422 and embedding dim: 50
# player1__id-team1__id: cardinality : 1600 and embedding dim: 50
# player1__id-team2__id: cardinality : 10963 and embedding dim: 50
# player2__id-player3__id: cardinality : 2035 and embedding dim: 50
# player2__id-player4__id: cardinality : 2285 and embedding dim: 50
# player2__id-player5__id: cardinality : 2380 and embedding dim: 50
# player2__id-player6__id: cardinality : 12144 and embedding dim: 50
# player2__id-player7__id: cardinality : 12616 and embedding dim: 50
# player2__id-player8__id: cardinality : 12797 and embedding dim: 50
# player2__id-player9__id: cardinality : 12925 and embedding dim: 50
# player2__id-player10__id: cardinality : 12767 and embedding dim: 50
# player2__id-team1__id: cardinality : 1786 and embedding dim: 50
# player2__id-team2__id: cardinality : 11435 and embedding dim: 50
# player3__id-player4__id: cardinality : 2161 and embedding dim: 50
# player3__id-player5__id: cardinality : 2371 and embedding dim: 50
# player3__id-player6__id: cardinality : 12349 and embedding dim: 50
# player3__id-player7__id: cardinality : 12809 and embedding dim: 50
# player3__id-player8__id: cardinality : 12989 and embedding dim: 50
# player3__id-player9__id: cardinality : 13097 and embedding dim: 50
# player3__id-player10__id: cardinality : 12977 and embedding dim: 50
# player3__id-team1__id: cardinality : 1892 and embedding dim: 50
# player3__id-team2__id: cardinality : 11641 and embedding dim: 50
# player4__id-player5__id: cardinality : 2225 and embedding dim: 50
# player4__id-player6__id: cardinality : 12450 and embedding dim: 50
# player4__id-player7__id: cardinality : 12908 and embedding dim: 50
# player4__id-player8__id: cardinality : 13095 and embedding dim: 50
# player4__id-player9__id: cardinality : 13195 and embedding dim: 50
# player4__id-player10__id: cardinality : 13045 and embedding dim: 50
# player4__id-team1__id: cardinality : 1962 and embedding dim: 50
# player4__id-team2__id: cardinality : 11768 and embedding dim: 50
# player5__id-player6__id: cardinality : 12298 and embedding dim: 50
# player5__id-player7__id: cardinality : 12762 and embedding dim: 50
# player5__id-player8__id: cardinality : 12942 and embedding dim: 50
# player5__id-player9__id: cardinality : 13057 and embedding dim: 50
# player5__id-player10__id: cardinality : 12895 and embedding dim: 50
# player5__id-team1__id: cardinality : 1953 and embedding dim: 50
# player5__id-team2__id: cardinality : 11642 and embedding dim: 50
# player6__id-player7__id: cardinality : 2350 and embedding dim: 50
# player6__id-player8__id: cardinality : 2657 and embedding dim: 50
# player6__id-player9__id: cardinality : 2849 and embedding dim: 50
# player6__id-player10__id: cardinality : 2894 and embedding dim: 50
# player6__id-team1__id: cardinality : 10333 and embedding dim: 50
# player6__id-team2__id: cardinality : 2224 and embedding dim: 50
# player7__id-player8__id: cardinality : 2545 and embedding dim: 50
# player7__id-player9__id: cardinality : 2901 and embedding dim: 50
# player7__id-player10__id: cardinality : 3028 and embedding dim: 50
# player7__id-team1__id: cardinality : 11042 and embedding dim: 50
# player7__id-team2__id: cardinality : 2471 and embedding dim: 50
# player8__id-player9__id: cardinality : 2726 and embedding dim: 50
# player8__id-player10__id: cardinality : 2997 and embedding dim: 50
# player8__id-team1__id: cardinality : 11357 and embedding dim: 50
# player8__id-team2__id: cardinality : 2567 and embedding dim: 50
# player9__id-player10__id: cardinality : 2825 and embedding dim: 50
# player9__id-team1__id: cardinality : 11538 and embedding dim: 50
# player9__id-team2__id: cardinality : 2667 and embedding dim: 50
# player10__id-team1__id: cardinality : 11343 and embedding dim: 50
# player10__id-team2__id: cardinality : 2654 and embedding dim: 50
# team1__id-team2__id: cardinality : 9339 and embedding dim: 50
# player1__id-player2__id-player3__id: cardinality : 2251 and embedding dim: 50
# player1__id-player2__id-player4__id: cardinality : 2469 and embedding dim: 50
# player1__id-player2__id-player5__id: cardinality : 2543 and embedding dim: 50
# player1__id-player2__id-player6__id: cardinality : 12570 and embedding dim: 50
# player1__id-player2__id-player7__id: cardinality : 12970 and embedding dim: 50
# player1__id-player2__id-player8__id: cardinality : 13104 and embedding dim: 50
# player1__id-player2__id-player9__id: cardinality : 13211 and embedding dim: 50
# player1__id-player2__id-player10__id: cardinality : 13087 and embedding dim: 50
# player1__id-player2__id-team1__id: cardinality : 2043 and embedding dim: 50
# player1__id-player2__id-team2__id: cardinality : 11953 and embedding dim: 50
# player1__id-player3__id-player4__id: cardinality : 2471 and embedding dim: 50
# player1__id-player3__id-player5__id: cardinality : 2627 and embedding dim: 50
# player1__id-player3__id-player6__id: cardinality : 12884 and embedding dim: 50
# player1__id-player3__id-player7__id: cardinality : 13238 and embedding dim: 50
# player1__id-player3__id-player8__id: cardinality : 13367 and embedding dim: 50
# player1__id-player3__id-player9__id: cardinality : 13457 and embedding dim: 50
# player1__id-player3__id-player10__id: cardinality : 13352 and embedding dim: 50
# player1__id-player3__id-team1__id: cardinality : 2254 and embedding dim: 50
# player1__id-player3__id-team2__id: cardinality : 12271 and embedding dim: 50
# player1__id-player4__id-player5__id: cardinality : 2582 and embedding dim: 50
# player1__id-player4__id-player6__id: cardinality : 13123 and embedding dim: 50
# player1__id-player4__id-player7__id: cardinality : 13463 and embedding dim: 50
# player1__id-player4__id-player8__id: cardinality : 13602 and embedding dim: 50
# player1__id-player4__id-player9__id: cardinality : 13669 and embedding dim: 50
# player1__id-player4__id-player10__id: cardinality : 13569 and embedding dim: 50
# player1__id-player4__id-team1__id: cardinality : 2381 and embedding dim: 50
# player1__id-player4__id-team2__id: cardinality : 12563 and embedding dim: 50
# player1__id-player5__id-player6__id: cardinality : 13123 and embedding dim: 50
# player1__id-player5__id-player7__id: cardinality : 13467 and embedding dim: 50
# player1__id-player5__id-player8__id: cardinality : 13616 and embedding dim: 50
# player1__id-player5__id-player9__id: cardinality : 13676 and embedding dim: 50
# player1__id-player5__id-player10__id: cardinality : 13574 and embedding dim: 50
# player1__id-player5__id-team1__id: cardinality : 2396 and embedding dim: 50
# player1__id-player5__id-team2__id: cardinality : 12593 and embedding dim: 50
# player1__id-player6__id-player7__id: cardinality : 12699 and embedding dim: 50
# player1__id-player6__id-player8__id: cardinality : 13084 and embedding dim: 50
# player1__id-player6__id-player9__id: cardinality : 13289 and embedding dim: 50
# player1__id-player6__id-player10__id: cardinality : 13331 and embedding dim: 50
# player1__id-player6__id-team1__id: cardinality : 12053 and embedding dim: 50
# player1__id-player6__id-team2__id: cardinality : 12418 and embedding dim: 50
# player1__id-player7__id-player8__id: cardinality : 13013 and embedding dim: 50
# player1__id-player7__id-player9__id: cardinality : 13354 and embedding dim: 50
# player1__id-player7__id-player10__id: cardinality : 13453 and embedding dim: 50
# player1__id-player7__id-team1__id: cardinality : 12495 and embedding dim: 50
# player1__id-player7__id-team2__id: cardinality : 12759 and embedding dim: 50
# player1__id-player8__id-player9__id: cardinality : 13193 and embedding dim: 50
# player1__id-player8__id-player10__id: cardinality : 13395 and embedding dim: 50
# player1__id-player8__id-team1__id: cardinality : 12684 and embedding dim: 50
# player1__id-player8__id-team2__id: cardinality : 12942 and embedding dim: 50
# player1__id-player9__id-player10__id: cardinality : 13260 and embedding dim: 50
# player1__id-player9__id-team1__id: cardinality : 12802 and embedding dim: 50
# player1__id-player9__id-team2__id: cardinality : 13064 and embedding dim: 50
# player1__id-player10__id-team1__id: cardinality : 12666 and embedding dim: 50
# player1__id-player10__id-team2__id: cardinality : 12996 and embedding dim: 50
# player1__id-team1__id-team2__id: cardinality : 11309 and embedding dim: 50
# player2__id-player3__id-player4__id: cardinality : 2419 and embedding dim: 50
# player2__id-player3__id-player5__id: cardinality : 2580 and embedding dim: 50
# player2__id-player3__id-player6__id: cardinality : 12805 and embedding dim: 50
# player2__id-player3__id-player7__id: cardinality : 13176 and embedding dim: 50
# player2__id-player3__id-player8__id: cardinality : 13312 and embedding dim: 50
# player2__id-player3__id-player9__id: cardinality : 13401 and embedding dim: 50
# player2__id-player3__id-player10__id: cardinality : 13285 and embedding dim: 50
# player2__id-player3__id-team1__id: cardinality : 2201 and embedding dim: 50
# player2__id-player3__id-team2__id: cardinality : 12176 and embedding dim: 50
# player2__id-player4__id-player5__id: cardinality : 2625 and embedding dim: 50
# player2__id-player4__id-player6__id: cardinality : 13181 and embedding dim: 50
# player2__id-player4__id-player7__id: cardinality : 13520 and embedding dim: 50
# player2__id-player4__id-player8__id: cardinality : 13641 and embedding dim: 50
# player2__id-player4__id-player9__id: cardinality : 13714 and embedding dim: 50
# player2__id-player4__id-player10__id: cardinality : 13603 and embedding dim: 50
# player2__id-player4__id-team1__id: cardinality : 2438 and embedding dim: 50
# player2__id-player4__id-team2__id: cardinality : 12626 and embedding dim: 50
# player2__id-player5__id-player6__id: cardinality : 13245 and embedding dim: 50
# player2__id-player5__id-player7__id: cardinality : 13572 and embedding dim: 50
# player2__id-player5__id-player8__id: cardinality : 13696 and embedding dim: 50
# player2__id-player5__id-player9__id: cardinality : 13765 and embedding dim: 50
# player2__id-player5__id-player10__id: cardinality : 13666 and embedding dim: 50
# player2__id-player5__id-team1__id: cardinality : 2512 and embedding dim: 50
# player2__id-player5__id-team2__id: cardinality : 12733 and embedding dim: 50
# player2__id-player6__id-player7__id: cardinality : 13006 and embedding dim: 50
# player2__id-player6__id-player8__id: cardinality : 13358 and embedding dim: 50
# player2__id-player6__id-player9__id: cardinality : 13557 and embedding dim: 50
# player2__id-player6__id-player10__id: cardinality : 13577 and embedding dim: 50
# player2__id-player6__id-team1__id: cardinality : 12363 and embedding dim: 50
# player2__id-player6__id-team2__id: cardinality : 12758 and embedding dim: 50
# player2__id-player7__id-player8__id: cardinality : 13294 and embedding dim: 50
# player2__id-player7__id-player9__id: cardinality : 13617 and embedding dim: 50
# player2__id-player7__id-player10__id: cardinality : 13694 and embedding dim: 50
# player2__id-player7__id-team1__id: cardinality : 12800 and embedding dim: 50
# player2__id-player7__id-team2__id: cardinality : 13055 and embedding dim: 50
# player2__id-player8__id-player9__id: cardinality : 13460 and embedding dim: 50
# player2__id-player8__id-player10__id: cardinality : 13636 and embedding dim: 50
# player2__id-player8__id-team1__id: cardinality : 12957 and embedding dim: 50
# player2__id-player8__id-team2__id: cardinality : 13234 and embedding dim: 50
# player2__id-player9__id-player10__id: cardinality : 13510 and embedding dim: 50
# player2__id-player9__id-team1__id: cardinality : 13064 and embedding dim: 50
# player2__id-player9__id-team2__id: cardinality : 13346 and embedding dim: 50
# player2__id-player10__id-team1__id: cardinality : 12941 and embedding dim: 50
# player2__id-player10__id-team2__id: cardinality : 13271 and embedding dim: 50
# player2__id-team1__id-team2__id: cardinality : 11656 and embedding dim: 50
# player3__id-player4__id-player5__id: cardinality : 2542 and embedding dim: 50
# player3__id-player4__id-player6__id: cardinality : 13056 and embedding dim: 50
# player3__id-player4__id-player7__id: cardinality : 13415 and embedding dim: 50
# player3__id-player4__id-player8__id: cardinality : 13546 and embedding dim: 50
# player3__id-player4__id-player9__id: cardinality : 13634 and embedding dim: 50
# player3__id-player4__id-player10__id: cardinality : 13518 and embedding dim: 50
# player3__id-player4__id-team1__id: cardinality : 2328 and embedding dim: 50
# player3__id-player4__id-team2__id: cardinality : 12457 and embedding dim: 50
# player3__id-player5__id-player6__id: cardinality : 13246 and embedding dim: 50
# player3__id-player5__id-player7__id: cardinality : 13578 and embedding dim: 50
# player3__id-player5__id-player8__id: cardinality : 13690 and embedding dim: 50
# player3__id-player5__id-player9__id: cardinality : 13764 and embedding dim: 50
# player3__id-player5__id-player10__id: cardinality : 13667 and embedding dim: 50
# player3__id-player5__id-team1__id: cardinality : 2502 and embedding dim: 50
# player3__id-player5__id-team2__id: cardinality : 12703 and embedding dim: 50
# player3__id-player6__id-player7__id: cardinality : 13185 and embedding dim: 50
# player3__id-player6__id-player8__id: cardinality : 13518 and embedding dim: 50
# player3__id-player6__id-player9__id: cardinality : 13700 and embedding dim: 50
# player3__id-player6__id-player10__id: cardinality : 13721 and embedding dim: 50
# player3__id-player6__id-team1__id: cardinality : 12588 and embedding dim: 50
# player3__id-player6__id-team2__id: cardinality : 12920 and embedding dim: 50
# player3__id-player7__id-player8__id: cardinality : 13445 and embedding dim: 50
# player3__id-player7__id-player9__id: cardinality : 13752 and embedding dim: 50
# player3__id-player7__id-player10__id: cardinality : 13844 and embedding dim: 50
# player3__id-player7__id-team1__id: cardinality : 12996 and embedding dim: 50
# player3__id-player7__id-team2__id: cardinality : 13230 and embedding dim: 50
# player3__id-player8__id-player9__id: cardinality : 13612 and embedding dim: 50
# player3__id-player8__id-player10__id: cardinality : 13786 and embedding dim: 50
# player3__id-player8__id-team1__id: cardinality : 13151 and embedding dim: 50
# player3__id-player8__id-team2__id: cardinality : 13391 and embedding dim: 50
# player3__id-player9__id-player10__id: cardinality : 13670 and embedding dim: 50
# player3__id-player9__id-team1__id: cardinality : 13256 and embedding dim: 50
# player3__id-player9__id-team2__id: cardinality : 13498 and embedding dim: 50
# player3__id-player10__id-team1__id: cardinality : 13138 and embedding dim: 50
# player3__id-player10__id-team2__id: cardinality : 13435 and embedding dim: 50
# player3__id-team1__id-team2__id: cardinality : 11877 and embedding dim: 50
# player4__id-player5__id-player6__id: cardinality : 13069 and embedding dim: 50
# player4__id-player5__id-player7__id: cardinality : 13434 and embedding dim: 50
# player4__id-player5__id-player8__id: cardinality : 13573 and embedding dim: 50
# player4__id-player5__id-player9__id: cardinality : 13647 and embedding dim: 50
# player4__id-player5__id-player10__id: cardinality : 13534 and embedding dim: 50
# player4__id-player5__id-team1__id: cardinality : 2377 and embedding dim: 50
# player4__id-player5__id-team2__id: cardinality : 12507 and embedding dim: 50
# player4__id-player6__id-player7__id: cardinality : 13283 and embedding dim: 50
# player4__id-player6__id-player8__id: cardinality : 13598 and embedding dim: 50
# player4__id-player6__id-player9__id: cardinality : 13782 and embedding dim: 50
# player4__id-player6__id-player10__id: cardinality : 13788 and embedding dim: 50
# player4__id-player6__id-team1__id: cardinality : 12701 and embedding dim: 50
# player4__id-player6__id-team2__id: cardinality : 13005 and embedding dim: 50
# player4__id-player7__id-player8__id: cardinality : 13525 and embedding dim: 50
# player4__id-player7__id-player9__id: cardinality : 13834 and embedding dim: 50
# player4__id-player7__id-player10__id: cardinality : 13913 and embedding dim: 50
# player4__id-player7__id-team1__id: cardinality : 13098 and embedding dim: 50
# player4__id-player7__id-team2__id: cardinality : 13309 and embedding dim: 50
# player4__id-player8__id-player9__id: cardinality : 13694 and embedding dim: 50
# player4__id-player8__id-player10__id: cardinality : 13857 and embedding dim: 50
# player4__id-player8__id-team1__id: cardinality : 13268 and embedding dim: 50
# player4__id-player8__id-team2__id: cardinality : 13483 and embedding dim: 50
# player4__id-player9__id-player10__id: cardinality : 13733 and embedding dim: 50
# player4__id-player9__id-team1__id: cardinality : 13358 and embedding dim: 50
# player4__id-player9__id-team2__id: cardinality : 13578 and embedding dim: 50
# player4__id-player10__id-team1__id: cardinality : 13244 and embedding dim: 50
# player4__id-player10__id-team2__id: cardinality : 13508 and embedding dim: 50
# player4__id-team1__id-team2__id: cardinality : 12013 and embedding dim: 50
# player5__id-player6__id-player7__id: cardinality : 13161 and embedding dim: 50
# player5__id-player6__id-player8__id: cardinality : 13483 and embedding dim: 50
# player5__id-player6__id-player9__id: cardinality : 13669 and embedding dim: 50
# player5__id-player6__id-player10__id: cardinality : 13677 and embedding dim: 50
# player5__id-player6__id-team1__id: cardinality : 12605 and embedding dim: 50
# player5__id-player6__id-team2__id: cardinality : 12880 and embedding dim: 50
# player5__id-player7__id-player8__id: cardinality : 13401 and embedding dim: 50
# player5__id-player7__id-player9__id: cardinality : 13719 and embedding dim: 50
# player5__id-player7__id-player10__id: cardinality : 13800 and embedding dim: 50
# player5__id-player7__id-team1__id: cardinality : 13019 and embedding dim: 50
# player5__id-player7__id-team2__id: cardinality : 13181 and embedding dim: 50
# player5__id-player8__id-player9__id: cardinality : 13569 and embedding dim: 50
# player5__id-player8__id-player10__id: cardinality : 13748 and embedding dim: 50
# player5__id-player8__id-team1__id: cardinality : 13190 and embedding dim: 50
# player5__id-player8__id-team2__id: cardinality : 13353 and embedding dim: 50
# player5__id-player9__id-player10__id: cardinality : 13619 and embedding dim: 50
# player5__id-player9__id-team1__id: cardinality : 13274 and embedding dim: 50
# player5__id-player9__id-team2__id: cardinality : 13448 and embedding dim: 50
# player5__id-player10__id-team1__id: cardinality : 13132 and embedding dim: 50
# player5__id-player10__id-team2__id: cardinality : 13382 and embedding dim: 50
# player5__id-team1__id-team2__id: cardinality : 11955 and embedding dim: 50
# player6__id-player7__id-player8__id: cardinality : 2831 and embedding dim: 50
# player6__id-player7__id-player9__id: cardinality : 3122 and embedding dim: 50
# player6__id-player7__id-player10__id: cardinality : 3222 and embedding dim: 50
# player6__id-player7__id-team1__id: cardinality : 11790 and embedding dim: 50
# player6__id-player7__id-team2__id: cardinality : 2742 and embedding dim: 50
# player6__id-player8__id-player9__id: cardinality : 3107 and embedding dim: 50
# player6__id-player8__id-player10__id: cardinality : 3301 and embedding dim: 50
# player6__id-player8__id-team1__id: cardinality : 12342 and embedding dim: 50
# player6__id-player8__id-team2__id: cardinality : 2969 and embedding dim: 50
# player6__id-player9__id-player10__id: cardinality : 3255 and embedding dim: 50
# player6__id-player9__id-team1__id: cardinality : 12596 and embedding dim: 50
# player6__id-player9__id-team2__id: cardinality : 3129 and embedding dim: 50
# player6__id-player10__id-team1__id: cardinality : 12643 and embedding dim: 50
# player6__id-player10__id-team2__id: cardinality : 3160 and embedding dim: 50
# player6__id-team1__id-team2__id: cardinality : 11412 and embedding dim: 50
# player7__id-player8__id-player9__id: cardinality : 3046 and embedding dim: 50
# player7__id-player8__id-player10__id: cardinality : 3251 and embedding dim: 50
# player7__id-player8__id-team1__id: cardinality : 12228 and embedding dim: 50
# player7__id-player8__id-team2__id: cardinality : 2905 and embedding dim: 50
# player7__id-player9__id-player10__id: cardinality : 3296 and embedding dim: 50
# player7__id-player9__id-team1__id: cardinality : 12670 and embedding dim: 50
# player7__id-player9__id-team2__id: cardinality : 3185 and embedding dim: 50
# player7__id-player10__id-team1__id: cardinality : 12812 and embedding dim: 50
# player7__id-player10__id-team2__id: cardinality : 3283 and embedding dim: 50
# player7__id-team1__id-team2__id: cardinality : 11877 and embedding dim: 50
# player8__id-player9__id-player10__id: cardinality : 3180 and embedding dim: 50
# player8__id-player9__id-team1__id: cardinality : 12458 and embedding dim: 50
# player8__id-player9__id-team2__id: cardinality : 3047 and embedding dim: 50
# player8__id-player10__id-team1__id: cardinality : 12724 and embedding dim: 50
# player8__id-player10__id-team2__id: cardinality : 3249 and embedding dim: 50
# player8__id-team1__id-team2__id: cardinality : 12104 and embedding dim: 50
# player9__id-player10__id-team1__id: cardinality : 12531 and embedding dim: 50
# player9__id-player10__id-team2__id: cardinality : 3124 and embedding dim: 50
# player9__id-team1__id-team2__id: cardinality : 12273 and embedding dim: 50
# player10__id-team1__id-team2__id: cardinality : 12195 and embedding dim: 50
